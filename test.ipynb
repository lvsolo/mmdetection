# %%
# !python demo/image_demo.py images/animals.png \
        configs/mm_grounding_dino/grounding_dino_swin-l_pretrain_all.py \
        --weights /home/lvsolo/Downloads/grounding_dino_swin-l_pretrain_all-56d69e78.pth \
        --texts '$: coco' --show
# Out:
# Loads checkpoint by local backend from path: /home/lvsolo/Downloads/grounding_dino_swin-l_pretrain_all-56d69e78.pth
# wwwwwwwwwwwwwwwwwwwwww: 127.0.0.1 7890
# ffffffffffffffffffffff: https://huggingface.co/bert-base-uncased/resolve/main/tokenizer_config.json /home/lvsolo/.cache/huggingface/hub
# /home/lvsolo/anaconda3/envs/mmdet/lib/python3.8/site-packages/transformers/tokenization_utils_base.py:1601: FutureWarning: `clean_up_tokenization_spaces` was not set. It will be set to `True` by default. This behavior will be depracted in transformers v4.45, and will be then set to `False` by default. For more details check this issue: https://github.com/huggingface/transformers/issues/31884
#   warnings.warn(
# wwwwwwwwwwwwwwwwwwwwww: huggingface.co 443
# ffffffffffffffffffffff: https://huggingface.co/bert-base-uncased/resolve/main/config.json /home/lvsolo/.cache/huggingface/hub
# ...

# %%
# !pip install  mmcv==2.0.0rc4 mmengine fairscale transformers -i https://pypi.tuna.tsinghua.edu.cn/simple
# Out:
# Looking in indexes: https://pypi.tuna.tsinghua.edu.cn/simple
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 9.5/9.5 MB 3.6 MB/s eta 0:00:0000:0100:01
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 417.5/417.5 kB 5.0 MB/s eta 0:00:00a 0:00:01
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 778.9/778.9 kB 5.8 MB/s eta 0:00:00a 0:00:01
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 436.3/436.3 kB 1.5 MB/s eta 0:00:00a 0:00:01
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 3.6/3.6 MB 5.6 MB/s eta 0:00:00a 0:00:01
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 177.6/177.6 kB 5.5 MB/s eta 0:00:00
# ...

# %%
from transformers import AutoTokenizer, AutoModelForSeq2SeqLM
tokenizer = AutoTokenizer.from_pretrained("google-bert/bert-base-uncased",proxies={'all':"http://127.0.0.1:7890"})
# model = AutoModelForSeq2SeqLM.from_pretrained("google-bert/bert-base-uncased")
# Out:
# a aapppppppppp: {'all': 'http://127.0.0.1:7890'}
# apppppppppp: {'all': 'http://127.0.0.1:7890'}
# qqqqqqqqqqqqqqqq: ['https://huggingface.co', 'https', 'all://huggingface.co', 'all'] {'all': 'http://127.0.0.1:7890'}
# apppppppppp: http://127.0.0.1:7890 {'all': 'http://127.0.0.1:7890'}
# pppppppppp: http://127.0.0.1:7890 http://127.0.0.1:7890
# qqqqqqqqqqqqqqqq: ['https://huggingface.co', 'https', 'all://huggingface.co', 'all'] {'all': 'http://127.0.0.1:7890'}
# rrrrrrrrrrrrrrrrrr url: /google-bert/bert-base-uncased/resolve/main/tokenizer_config.json
# ffffffffffffffffffffff: https://huggingface.co/google-bert/bert-base-uncased/resolve/main/tokenizer_config.json /home/lvsolo/.cache/huggingface/hub
